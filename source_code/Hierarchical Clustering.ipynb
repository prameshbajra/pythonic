# %% [markdown]
# # Hierarchical Clustering - Unsupervised Learning
# <br><br>
#
# **Learning from : https://pythonprogramming.net/hierarchical-clustering-machine-learning-python-scikit-learn/**

# %%
import numpy as np
from sklearn.cluster import MeanShift
from sklearn.datasets.samples_generator import make_blobs
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

# %%
centers = [[1,1],[5,5],[3,10]]
X, _ = make_blobs(n_samples = 500, centers = centers, cluster_std = 1)
# Out:
# (500, 2)

# %%
plt.scatter(X[:,0],X[:,1])
plt.xlabel("X - Co ordinate")
plt.ylabel("Y - Co ordinate")
plt.show()

# %%
ms = MeanShift()
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_
cluster_centers
# Out:
# array([[4.93056847, 5.00852746],
#        [3.05893077, 9.90634095],
#        [1.07541213, 1.02776998]])

# %%
colors = 10*['r.','g.','b.','c.','k.','y.','m.']
for i in range(len(X)):
    plt.plot(X[i][0], X[i][1], colors[labels[i]], markersize = 7)

    
print(cluster_centers[:,0], cluster_centers[:,1])
plt.scatter(cluster_centers[:,0],cluster_centers[:,1],
            marker="x",color='k', s=150, linewidths = 5, zorder=10)

plt.show()
# Out:
# [4.93056847 3.05893077 1.07541213] [5.00852746 9.90634095 1.02776998]
